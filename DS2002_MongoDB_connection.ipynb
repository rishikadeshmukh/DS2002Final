# %% [markdown]
# <a href="https://colab.research.google.com/github/rishikadeshmukh/DS2002Final/blob/main/DS2002_MongoDB_connection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://ammu19491973:PgxMbasffX6pUgCP@cluster0.mn934.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")

# %%
db = client['education_analysis']

# %%
import pandas as pd

# %%
country = pd.read_csv('/Users/ananyasai/Downloads/cleaned_global_country_development.csv')

# %%
uni = pd.read_csv('/Users/ananyasai/Downloads/cleaned_world_university_rank.csv')

# %%
country_collection = db['country']
uni_collection = db['uni']

# %%
country_records = country.to_dict(orient='records')
uni_records = uni.to_dict(orient='records')

# %%
country_collection.insert_many(country_records)
uni_collection.insert_many(uni_records)
# Out:
# InsertManyResult([ObjectId('6751c10495637658c25dbb25'), ObjectId('6751c10495637658c25dbb26'), ObjectId('6751c10495637658c25dbb27'), ObjectId('6751c10495637658c25dbb28'), ObjectId('6751c10495637658c25dbb29'), ObjectId('6751c10495637658c25dbb2a'), ObjectId('6751c10495637658c25dbb2b'), ObjectId('6751c10495637658c25dbb2c'), ObjectId('6751c10495637658c25dbb2d'), ObjectId('6751c10495637658c25dbb2e'), ObjectId('6751c10495637658c25dbb2f'), ObjectId('6751c10495637658c25dbb30'), ObjectId('6751c10495637658c25dbb31'), ObjectId('6751c10495637658c25dbb32'), ObjectId('6751c10495637658c25dbb33'), ObjectId('6751c10495637658c25dbb34'), ObjectId('6751c10495637658c25dbb35'), ObjectId('6751c10495637658c25dbb36'), ObjectId('6751c10495637658c25dbb37'), ObjectId('6751c10495637658c25dbb38'), ObjectId('6751c10495637658c25dbb39'), ObjectId('6751c10495637658c25dbb3a'), ObjectId('6751c10495637658c25dbb3b'), ObjectId('6751c10495637658c25dbb3c'), ObjectId('6751c10495637658c25dbb3d'), ObjectId('6751c10495637658c25d
# ...
